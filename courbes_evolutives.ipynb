# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("evolutions.csv")
plt.plot(df["Tours"], df["Lapins"], label="Lapins")
plt.plot(df["Tours"], df["Renards"], label="Renards")
plt.xlabel("Tours")
plt.ylabel("Nombre de vivants")
plt.legend()
plt.show()
